# %% [markdown]
# # 02: Feature Engineering and Index Calculation
#
# This notebook handles:
# - Loading cleaned data from data/processed/
# - Creating new features for analysis
# - Calculating Affordability Stress Index (ASI)
# - Saving the ASI scores

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Load Processed Data

# %%
# Load the cleaned data
# df = pd.read_csv('../data/processed/metros_master.csv')

# %% [markdown]
# ## Feature Engineering

# %%
# Create new features
# Example: price-to-income ratio, rent burden, etc.

# %% [markdown]
# ## Calculate Affordability Stress Index (ASI)

# %%
# Calculate the ASI score
# This could be a weighted combination of multiple affordability metrics

# %% [markdown]
# ## Visualize Index Distribution

# %%
# Create visualizations of the ASI scores
# plt.figure(figsize=(10, 6))
# plt.hist(df['asi_score'], bins=30)
# plt.xlabel('ASI Score')
# plt.ylabel('Frequency')
# plt.title('Distribution of Affordability Stress Index')
# plt.savefig('../report/figures/asi_distribution.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Save ASI Scores

# %%
# Save the ASI scores
# asi_df.to_csv('../data/processed/asi_scores.csv', index=False)
