# %% [markdown]
# # 03: Clustering Analysis
#
# This notebook handles:
# - Loading ASI scores and metro data
# - Performing clustering analysis to group metros by affordability patterns
# - Visualizing clusters
# - Generating insights and reports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
# Load the processed data and ASI scores
# metros_df = pd.read_csv('../data/processed/metros_master.csv')
# asi_df = pd.read_csv('../data/processed/asi_scores.csv')

# %% [markdown]
# ## Prepare Data for Clustering

# %%
# Select features for clustering
# Standardize features
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## Determine Optimal Number of Clusters

# %%
# Use elbow method or silhouette analysis
# inertias = []
# K_range = range(2, 11)
# for k in K_range:
#     kmeans = KMeans(n_clusters=k, random_state=42)
#     kmeans.fit(X_scaled)
#     inertias.append(kmeans.inertia_)

# plt.figure(figsize=(10, 6))
# plt.plot(K_range, inertias, 'bo-')
# plt.xlabel('Number of Clusters')
# plt.ylabel('Inertia')
# plt.title('Elbow Method for Optimal K')
# plt.savefig('../report/figures/elbow_plot.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Perform Clustering

# %%
# Fit the final clustering model
# optimal_k = 4  # Adjust based on elbow plot
# kmeans = KMeans(n_clusters=optimal_k, random_state=42)
# clusters = kmeans.fit_predict(X_scaled)
# df['cluster'] = clusters

# %% [markdown]
# ## Visualize Clusters

# %%
# Use PCA for dimensionality reduction to visualize clusters
# pca = PCA(n_components=2)
# X_pca = pca.fit_transform(X_scaled)

# plt.figure(figsize=(12, 8))
# scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='viridis', alpha=0.6)
# plt.colorbar(scatter)
# plt.xlabel('First Principal Component')
# plt.ylabel('Second Principal Component')
# plt.title('Metro Clusters based on Affordability Metrics')
# plt.savefig('../report/figures/cluster_visualization.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Analyze Cluster Characteristics

# %%
# Analyze characteristics of each cluster
# cluster_summary = df.groupby('cluster').mean()
# print(cluster_summary)

# %% [markdown]
# ## Export Results

# %%
# Save clustering results
# df.to_csv('../data/processed/metros_with_clusters.csv', index=False)
